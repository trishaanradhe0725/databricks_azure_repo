# %%
# %sql
describe extended true_catalog.bronze.tbl_sample

# %%
dbutils.fs.ls('/Volumes/true_catalog/bronze/kagle_dataset_raw')

# %%
spark.sql("DESCRIBE DETAIL true_catalog.bronze.tbl_sample").select("numFiles").show()

# %%
ride_df=spark.read.format('parquet').option('inferSchema',True).load('/Volumes/true_catalog/bronze/kagle_dataset_raw/nyc-rideshare-raw-data/rideshare_data.parquet')

# %%
ride_df.write.format('delta').option('mergeSchema',True).mode('overwrite').partitionBy('business').saveAsTable('true_catalog.bronze.tbl_nyc_rideshare')

# %%
spark.sql("DESCRIBE DETAIL true_catalog.bronze.tbl_nyc_rideshare").select("numFiles").show()

# %%
# %sql
DESCRIBE EXTENDED true_catalog.bronze.tbl_nyc_rideshare

# %%
spark.sql("DESCRIBE DETAIL true_catalog.gold.trips").select('numFiles').show()

# %%
# %sql
use catalog true_catalog;
use schema gold;
show tables;

# %%
# %sql
CREATE OR REPLACE VIEW true_catalog.gold.sample_view AS
SELECT * FROM true_catalog.bronze.tbl_sample

# %%
# %sql
describe formatted true_catalog.gold.sample_view

# %%
spark.sql("describe detail true_catalog.gold.trips").select('numFiles').show()

# %%
# %sql
optimize true_catalog.gold.trips zorder by (month_of_year)

# %%
spark.sql("describe detail true_catalog.gold.trips").select('numFiles').show()

# %%
username = "webadmin"
password = "MkSc@1510"
server   = "jdbc:sqlserver://mruali-databricks-practice.database.windows.net:1433;"
database = "murali_practice"

#server = (
    #"jdbc:sqlserver://mruali-databricks-practice.database.windows.net:1433;"
    #"database=murali_practice;"
    #"encrypt=true;"
    #"trustServerCertificate=false;"
    #"hostNameInCertificate=*.database.windows.net;"
    #"loginTimeout=30;"
#)

# %%
emp_df=spark.read\
  .format("jdbc")\
  .option("url", server)\
  .option("database", "murali_practice")\
  .option("dbtable", "[dbo].[Employees]")\
  .option("user", username)\
  .option("password", password)\
  .load()

# %%
emp_df.display()

# %%
emp_df_no_id = emp_df.drop("EmployeeID")

# %%
# %sql 
SET IDENTITY_INSERT dbo.Employees_write ON;

# %%
emp_df.write \
  .format("jdbc") \
  .option("url", server) \
  .option("database", "murali_practice")\
  .option("dbtable", "dbo.Employees_write") \
  .option("user", username) \
  .option("password", password) \
  .mode("overwrite") \
  .save()
