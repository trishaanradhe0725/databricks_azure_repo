# %%
# %sql
CREATE CATALOG IF NOT EXISTS True_catalog
MANAGED LOCATION 'abfss://databrickspractice@databrickspracticelearn.dfs.core.windows.net/own';

# %%
# %sql
USE CATALOG true_catalog;
CREATE SCHEMA IF NOT EXISTS bronze

# %%
# %sql
--checking table creation
CREATE TABLE IF NOT EXISTS true_catalog.bronze.tbl_sample(column_1 int, column_2 STRING )

# %%
# %sql
insert into true_catalog.bronze.tbl_sample values(1,'abc'),(2,'def'),(3,'ghi');
    
select * from true_catalog.bronze.tbl_sample

# %%
# %sql
CREATE VOLUME IF NOT EXISTS true_catalog.bronze.Kagle_dataset_raw;
    
SHOW VOLUMES LIKE 'true_catalog.bronze.Kagle_dataset_raw'
